# %%
import os
import sys
import torch

# This forces Python to look out at the parent folder (where both step1 and step2 live)
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# Now these imports will point to the right locations
from multihead_attention import MultiHeadAttention
from data_preperation_step1.dataloader import input_embeddings, max_length, output_dim

# %%
torch.manual_seed(123)

context_length = max_length
d_in = output_dim
d_out = d_in

mha = MultiHeadAttention(d_in, d_out, context_length, 0.0, num_heads=2)

batch = input_embeddings
context_vecs = mha(batch)

print("context_vecs.shape:", context_vecs.shape)
# Out:
# context_vecs.shape: torch.Size([8, 4, 256])
