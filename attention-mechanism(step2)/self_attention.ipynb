# %%
import torch
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 26
#      23         return context_vec
#      25 torch.manual_seed(123)
# ---> 26 sa_v1 = SelfAttention_v1(d_in, d_out)
#      27 print(sa_v1(inputs))
#
# NameError: name 'd_in' is not defined
